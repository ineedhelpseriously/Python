# %%
f=open('test.txt','r')
print(f.name)
print(f.mode)
f.close()
# Out:
# test.txt
# r

# %%
#context manager
with open('test.txt', 'r') as f:
    pass
print(f.closed)
# Out:
# True

# %%
with open('test.txt','r') as f:
    f_contents=f.read()
    print(f_contents)
# Out:
# >I needed a file to test my file handeling tech
# >That is the soul purpose I created this file
# >btw, screw you cashew, your fork is behind mine now.
# >enjoy the merge and pull issues
#
# -ineedhelseriously
# :>
#
#
#                                          %%%@@@@@@@%@@@@@@@%#%%
#                                %%@@@%#**+=-:.:-:::::::::.:::-+=*%@@@@@
#                             @@@%=:.................................-=#@%%@
#                         %@%%*:.........................................-+#%@@@
#                       @@@=.................................................:+@@@
#                     @@#:......................................................=%@@@
#                   @@*:..........................................................+@@
#                 @@@=.............................................................=@%@
#                @@#:...............................................................:@@@
# ...

# %%
with open('test.txt','r') as f:
    f_contents_lines=f.readlines()
    print(f_contents_lines)
# Out:
# ['>I needed a file to test my file handeling tech\n', '>That is the soul purpose I created this file\n', '>btw, screw you cashew, your fork is behind mine now.\n', '>enjoy the merge and pull issues\n', '\n', '-ineedhelseriously\n', ':>\n', '                                                                                                  \n', '                                                                                                                                                     \n', '                                         %%%@@@@@@@%@@@@@@@%#%%                                                                \n', '                               %%@@@%#**+=-:.:-:::::::::.:::-+=*%@@@@@                                                         \n', '                            @@@%=:.................................-=#@%%@                                                     \n', '                        %@%%*:.........................................-+#%@@@                     
# ...

# %%
with open('test.txt','r') as f:
    f_contents_line=f.readline()
    print(f_contents_line)
    f_contents_line=f.readline()
    print(f_contents_line)
    f_contents_line=f.readline()
    print(f_contents_line)
# Out:
# >I needed a file to test my file handeling tech
#
# >That is the soul purpose I created this file
#
# >btw, screw you cashew, your fork is behind mine now.

# %%
with open('test.txt', 'r') as f:
    for line in f:
        print(line, end='')
# Out:
# >I needed a file to test my file handeling tech
# >That is the soul purpose I created this file
# >btw, screw you cashew, your fork is behind mine now.
# >enjoy the merge and pull issues
#
# -ineedhelseriously
# :>
#
#
#                                          %%%@@@@@@@%@@@@@@@%#%%
#                                %%@@@%#**+=-:.:-:::::::::.:::-+=*%@@@@@
#                             @@@%=:.................................-=#@%%@
#                         %@%%*:.........................................-+#%@@@
#                       @@@=.................................................:+@@@
#                     @@#:......................................................=%@@@
#                   @@*:..........................................................+@@
#                 @@@=.............................................................=@%@
#                @@#:...............................................................:@@@
# ...

# %%
with open('test.txt','r') as f:
    
    size_to_read=10
    f_contents=f.read(size_to_read)
    
    while len(f_contents)>0:
        print(f_contents,end='*')
        f_contents=f.read(size_to_read)
# Out:
# >I needed *a file to *test my fi*le handeli*ng tech
# >T*hat is the* sole purp*ose I crea*ted this f*ile
# >btw, *screw you *cashew, yo*ur fork is* behind mi*ne now.
# >e*njoy the m*erge and p*ull issues*
#
# -ineedhe*lseriously*
# :>
#       *          *          *          *          *          *          *          *          *          *
#        *          *          *          *          *          *          *          *          *          *          *          *          *          *          *
#        *          *          *          *    %%%@@@*@@@@%@@@@@*@@%#%%    *          *          *          *          *          *          *
#          *          *          *  %%@@@%#***+=-:.:-::*:::::::.::*:-+=*%@@@@*@         *          *          *          *          *
#  *          *          *       @@@*%=:.......*..........*..........*......-=#@*%%@       *          *          *          *          *
# ...

# %%
with open('test.txt','r') as f:
    
    size_to_read=10
    f_contents=f.read(size_to_read)
    print(f_contents,end='')
    
    f.seek(0)
    f_contents=f.read(size_to_read)
    print(f_contents,end='')
# Out:
# >I needed >I needed

# %%
with open('test.txt', 'r') as f:
    f.write('BRUUH')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[12], line 2
#       1 with open('test.txt', 'r') as f:
# ----> 2     f.write('BRUUH')
#
# UnsupportedOperation: not writable

# %%
#creates the file if it doesnt exist
with open('test2.txt','w') as f:
    f.write('HII')
    f.seek(1)
    f.write('ELLO!')

# %%
with open('test.txt','r') as rf:
    with open('test_copy.txt','w') as wf:
        for line in rf:
            wf.write(line)

# %%
with open('freaky-tongue-emote.png','rb') as rf:
    with open('freaky-tongue-emote_copy.png','wb') as wf:
        for line in rf:
            wf.write(line)

# %%
with open('freaky-tongue-emote.png','rb') as rf:
    with open('freaky-tongue-emote_copy2.png','wb') as wf:
        chunk_size=1080
        rf_chunk=rf.read(chunk_size)
        while len(rf_chunk)>0:
            wf.write(rf_chunk)
            rf_chunk=rf.read(chunk_size)
